# %%
import git
repo_url ="https://github.com/PhonePe/pulse.git"
local_dir = "E:\srinivas\Phonepe_pulse_data"

git.Repo.clone_from(repo_url, local_dir)
# Out:
# <git.repo.base.Repo 'E:\\srinivas\\Phonepe_pulse_data\\.git'>

# %%
import pandas as pd
import os
import json


path1="E:/srinivas/Phonepe_pulse_data/data/aggregated/transaction/country/india/state/"
agg_trans_list=os.listdir(path1)

col1={'State': [], 'Year': [], 'Quarter': [], 'Transaction_type': [], 'Transaction_count': [],
        'Transaction_amount': []}

for state in agg_trans_list:
    cur_state=path1+state+"/"
    agg_year_list=os.listdir(cur_state)
    
    for year in agg_year_list:
        cur_year=cur_state+year+"/"
        agg_file_list=os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file=cur_year+file
            data=open(cur_file,'r')
            A=json.load(data)
            
            for i in A['data']['transactionData']:
                name = i['name']
                count = i['paymentInstruments'][0]['count']
                amount = i['paymentInstruments'][0]['amount']
                col1['Transaction_type'].append(name)
                col1['Transaction_count'].append(count)
                col1['Transaction_amount'].append(amount)
                col1['State'].append(state)
                col1['Year'].append(year)
                col1['Quarter'].append(int(file.strip('.json')))
            
df_agg_trans=pd.DataFrame(col1)

# %%
df_agg_trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4309                west-bengal  2023        4         Merchant payments
# 4310                west-bengal  2023        4     Peer-to-peer payments
# 4311                west-bengal  2023        4  Recharge & bill payments
# 4312                west-bengal  2023        4        Financial Services
# 4313                west-bengal  2023        4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
path2="E:/srinivas/Phonepe_pulse_data/data/aggregated/user/country/india/state/"
agg_user_list=os.listdir(path2)

col2={'State': [], 'Year': [], 'Quarter': [], 'Brands': [], 'Count': [],
            'Percentage': []}

for state in agg_user_list:
    cur_state=path2+state+"/"
    agg_year_list=os.listdir(cur_state)
    
    for year in agg_year_list:
        cur_year=cur_state+year+"/"
        agg_file_list=os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file=cur_year+file
            data=open(cur_file,'r')
            B=json.load(data)
            try:
                for i in B['data']['usersByDevice']:
                    brand=i['brand']
                    count=i['count']
                    percents=i['percentage']
                    col2['Brands'].append(brand)
                    col2['Count'].append(count)
                    col2['Percentage'].append(percents)
                    col2['State'].append(state)
                    col2['Year'].append(year)
                    col2['Quarter'].append(int(file.strip('.json')))
            except:
                pass

df_agg_user=pd.DataFrame(col2)

# %%
df_agg_user
# Out:
#                           State  Year  Quarter   Brands    Count  Percentage
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi     1665    0.247033
# 1     andaman-&-nicobar-islands  2018        1  Samsung     1445    0.214392
# 2     andaman-&-nicobar-islands  2018        1     Vivo      982    0.145697
# 3     andaman-&-nicobar-islands  2018        1     Oppo      501    0.074332
# 4     andaman-&-nicobar-islands  2018        1  OnePlus      332    0.049258
# ...                         ...   ...      ...      ...      ...         ...
# 6727                west-bengal  2022        1   Lenovo   330017    0.015056
# 6728                west-bengal  2022        1  Infinix   284678    0.012987
# 6729                west-bengal  2022        1     Asus   280347    0.012790
# 6730                west-bengal  2022        1    Apple   277752    0.012671
# 6731                west-bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
path3="E:/srinivas/Phonepe_pulse_data/data/map/transaction/hover/country/india/state/"
map_trans_list=os.listdir(path3)

col3={'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': [],
            'Amount': []}

for state in map_trans_list:
    cur_state=path3+state+"/"
    map_year_list=os.listdir(cur_state)
    
    for year in map_year_list:
        cur_year=cur_state+year+"/"
        map_file_list=os.listdir(cur_year)
        
        for file in map_file_list:
            cur_file=cur_year+file
            data=open(cur_file,'r')
            C=json.load(data)
            
            for i in C['data']['hoverDataList']:
                dist=i['name']
                count=i['metric'][0]['count']
                amount=i['metric'][0]['amount']
                col3['District'].append(dist)
                col3['Count'].append(count)
                col3['Amount'].append(amount)
                col3['State'].append(state)
                col3['Year'].append(year)
                col3['Quarter'].append(int(file.strip('.json')))
                
df_map_trans=pd.DataFrame(col3)

# %%
df_map_trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 17559                west-bengal  2023        4
# 17560                west-bengal  2023        4
# 17561                west-bengal  2023        4
# 17562                west-bengal  2023        4
# 17563                west-bengal  2023        4
#
#                                 District     Count        Amount
# 0      north and middle andaman district       442  9.316631e+05
# 1                 south andaman district      5688  1.256025e+07
# 2                      nicobars district       528  1.139849e+06
# 3      north and middle andaman district       825  1.317863e+06
# ...

# %%
path4="E:/srinivas/Phonepe_pulse_data/data/map/user/hover/country/india/state/"
map_user_list=os.listdir(path4)

col4={"State": [], "Year": [], "Quarter": [], "District": [],
            "RegisteredUser": [], "AppOpens": []}

for state in map_user_list:
    cur_state=path4+state+"/"
    map_year_list=os.listdir(cur_state)
    
    for year in map_year_list:
        cur_year=cur_state+year+"/"
        map_file_list=os.listdir(cur_year)
        
        for file in map_file_list:
            cur_file=cur_year+file
            data=open(cur_file,'r')
            D=json.load(data)
            
            for i in D['data']['hoverData'].items():
                dist=i[0]
                reg_user=i[1]['registeredUsers']
                app=i[1]['appOpens']
                col4['District'].append(dist)
                col4['RegisteredUser'].append(reg_user)
                col4['AppOpens'].append(app)
                col4['State'].append(state)
                col4['Year'].append(year)
                col4['Quarter'].append(int(file.strip('.json')))
                
df_map_user=pd.DataFrame(col4)

# %%
df_map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 17563                west-bengal  2023        4
# 17564                west-bengal  2023        4
# 17565                west-bengal  2023        4
# 17566                west-bengal  2023        4
# 17567                west-bengal  2023        4
#
#                                 District  RegisteredUser  AppOpens
# 0      north and middle andaman district             632         0
# 1                 south andaman district            5846         0
# 2                      nicobars district             262         0
# 3      north and middle andaman district             911         0
# ...

# %%
path5="E:/srinivas/Phonepe_pulse_data/data/top/transaction/country/india/state/"
top_trans_list=os.listdir(path5)

col5={'State': [], 'Year': [], 'Quarter': [], 'Pincode': [], 'Transaction_count': [],
            'Transaction_amount': []}

for state in top_trans_list:
    cur_state = path5 + state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            E = json.load(data)
            
            for i in E['data']['pincodes']:
                name = i['entityName']
                count = i['metric']['count']
                amount = i['metric']['amount']
                col5['Pincode'].append(name)
                col5['Transaction_count'].append(count)
                col5['Transaction_amount'].append(amount)
                col5['State'].append(state)
                col5['Year'].append(year)
                col5['Quarter'].append(int(file.strip('.json')))
                
df_top_trans = pd.DataFrame(col5)

# %%
df_top_trans
# Out:
#                           State  Year  Quarter Pincode  Transaction_count  \
# 0     andaman-&-nicobar-islands  2018        1  744101               1622
# 1     andaman-&-nicobar-islands  2018        1  744103               1223
# 2     andaman-&-nicobar-islands  2018        1  744102                969
# 3     andaman-&-nicobar-islands  2018        1  744105                685
# 4     andaman-&-nicobar-islands  2018        1  744104                340
# ...                         ...   ...      ...     ...                ...
# 8562                west-bengal  2023        4  721301            4133775
# 8563                west-bengal  2023        4  700001            3983241
# 8564                west-bengal  2023        4  732125            3950411
# 8565                west-bengal  2023        4  700039            3742452
# 8566                west-bengal  2023        4  700014            3652710
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# ...

# %%
path6="E:/srinivas/Phonepe_pulse_data/data/top/user/country/india/state/"
top_user_list=os.listdir(path6)

col6={'State': [], 'Year': [], 'Quarter': [], 'Pincode': [],
            'RegisteredUsers': []}

for state in top_user_list:
    cur_state = path6 + state + "/"
    top_year_list = os.listdir(cur_state)
    
    for year in top_year_list:
        cur_year = cur_state + year + "/"
        top_file_list = os.listdir(cur_year)
        
        for file in top_file_list:
            cur_file = cur_year + file
            data = open(cur_file, 'r')
            F = json.load(data)
            
            for i in F['data']['pincodes']:
                name = i['name']
                reg_users = i['registeredUsers']
                col6['Pincode'].append(name)
                col6['RegisteredUsers'].append(reg_users)
                col6['State'].append(state)
                col6['Year'].append(year)
                col6['Quarter'].append(int(file.strip('.json')))
df_top_user = pd.DataFrame(col6)

# %%
df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1  744103             1608
# 1     andaman-&-nicobar-islands  2018        1  744101             1108
# 2     andaman-&-nicobar-islands  2018        1  744105             1075
# 3     andaman-&-nicobar-islands  2018        1  744102             1006
# 4     andaman-&-nicobar-islands  2018        1  744104              272
# ...                         ...   ...      ...     ...              ...
# 8563                west-bengal  2023        4  700015           126663
# 8564                west-bengal  2023        4  742304           123320
# 8565                west-bengal  2023        4  721101           123088
# 8566                west-bengal  2023        4  700150           119283
# 8567                west-bengal  2023        4  700091           118578
#
# [8568 rows x 5 columns]

# %%
df_agg_trans.to_csv('agg_trans.csv',index=False)
df_agg_user.to_csv('agg_user.csv',index=False)
df_map_trans.to_csv('map_trans.csv',index=False)
df_map_user.to_csv('map_user.csv',index=False)
df_top_trans.to_csv('top_trans.csv',index=False)
df_top_user.to_csv('top_user.csv',index=False)

# %%
import mysql.connector

mydb=mysql.connector.connect(host="localhost",
                    user="root",
                    password="srinivas")

mycursor=mydb.cursor()

# %%
mycursor.execute("create database phonepe_pulse")

# %%
mydb=mysql.connector.connect(host="localhost",
                    user="root",
                    password="srinivas",
                    database="phonepe_pulse")

mycursor=mydb.cursor(buffered=True)

# %%
mycursor.execute("use phonepe_pulse")

# %%
mycursor.execute(
    "create table if not exists agg_trans(State varchar(100), Year int, Quarter int, Transaction_type varchar(100), Transaction_count int, Transaction_amount double)")

for i,row in df_agg_trans.iterrows():
    query="insert into agg_trans values(%s,%s,%s,%s,%s,%s)"
    mycursor.execute(query,tuple(row))
    mydb.commit()

# %%
mycursor.execute(
    "create table if not exists agg_user (State varchar(100), Year int, Quarter int, Brands varchar(100), Count int, Percentage double)")

for i, row in df_agg_user.iterrows():
    query = "insert into agg_user values (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(query, tuple(row))
    mydb.commit()

# %%
mycursor.execute(
    "create table if not exists map_trans (State varchar(100), Year int, Quarter int, District varchar(100), Count int, Amount double)")

for i, row in df_map_trans.iterrows():
    query = "insert into map_trans values (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(query, tuple(row))
    mydb.commit()

# %%
mycursor.execute(
    "create table if not exists map_user (State varchar(100), Year int, Quarter int, District varchar(100), Registered_user int, App_opens int)")

for i, row in df_map_user.iterrows():
    query = "insert into map_user values (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(query, tuple(row))
    mydb.commit()

# %%
mycursor.execute(
    "create table if not exists top_trans (State varchar(100), Year int, Quarter int, Pincode int, Transaction_count int, Transaction_amount double)")

for i, row in df_top_trans.iterrows():
    query = "insert into top_trans values (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(query, tuple(row))
    mydb.commit()

# %%
mycursor.execute(
    "create table if not exists top_user (State varchar(100), Year int, Quarter int, Pincode int, Registered_users int)")

for i, row in df_top_user.iterrows():
    query = "insert into top_user values (%s,%s,%s,%s,%s)"
    mycursor.execute(query, tuple(row))
    mydb.commit()
